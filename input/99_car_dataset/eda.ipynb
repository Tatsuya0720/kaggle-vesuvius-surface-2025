# %%
import numpy as np

# %%
points = np.load("./points.npy")
points.shape, points.min(), points.max()
# Out:
# ((500000, 3), np.float32(-0.9966722), np.float32(0.99327594))

# %%
sdf = np.load("./sdf.npy").shape
# Out:
# (500000,)
